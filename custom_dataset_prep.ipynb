# %% [markdown]
# <a href="https://colab.research.google.com/github/suvarnak/custom-dataset-maker/blob/master/custom_dataset_prep.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install google_images_download

# %%
# importing google_images_download module 
from google_images_download import google_images_download 

# creating object 
response = google_images_download.googleimagesdownload() 
search_queries = [ 
'under construction building jpg',	
'reinforced concrete frame construction', 
'unsafe scaffolding pictures' 
] 


def downloadimages(query): 
	# keywords is the search query 
	# format is the image file format 
	# limit is the number of images to be downloaded 
	# print urs is to print the image file url 
	# size is the image size which can 
	# be specified manually ("large, medium, icon") 
	# aspect ratio denotes the height width ratio 
	# of images to download. ("tall, square, wide, panoramic") 
	arguments = {"keywords": query, 
				"format": "jpg", 
				"limit":100, 
				"print_urls":True, 
				"size": "large", 
				"aspect_ratio": "panoramic"} 
	try: 
		response.download(arguments) 
	
	# Handling File NotFound Error	 
	except FileNotFoundError: 
		arguments = {"keywords": query, 
					"format": "jpg", 
					"limit":100, 
					"print_urls":True, 
					"size": "medium"} 
					
		# Providing arguments for the searched query 
		try: 
			# Downloading the photos based 
			# on the given arguments 
			response.download(arguments) 
		except: 
			pass

# Driver Code 
for query in search_queries: 
	downloadimages(query) 
	print()
# Out:
# Item no.: 1 --> Item name = under construction building jpg
# Evaluating...
# Starting Download...
# Image URL: https://upload.wikimedia.org/wikipedia/commons/6/66/Wells_Fargo_buildings_under_construction_in_Downtown_East_Minneapolis.jpg
# Completed Image ====> 1.Wells_Fargo_buildings_under_construction_in_Downtown_East_Minneapolis.jpg
# Image URL: https://previews.123rf.com/images/antonfoltin/antonfoltin0902/antonfoltin090200015/4323936-five-story-building-s-steel-frame-under-construction-.jpg
# Completed Image ====> 2.4323936-five-story-building-s-steel-frame-under-construction-.jpg
# Image URL: https://arizona.valorprepacademy.org/wp-content/uploads/sites/3/2019/06/image012.jpg
# Completed Image ====> 3.image012.jpg
# Image URL: https://upload.wikimedia.org/wikipedia/commons/6/64/Green_Point_Stadium_under_construction.JPG
# Completed Image ====> 4.Green_Point_Stadium_under_construction.JPG
# ...

# %%
# !ls -lt 'downloads/unsafe scaffolding pictures/'

# %%
from google.colab import files
# !zip -r downloaded_imgs.zip downloads 
# !ls 
files.download('downloaded_imgs.zip')
